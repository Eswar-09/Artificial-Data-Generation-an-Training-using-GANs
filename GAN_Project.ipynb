# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import tensorflow as tf 
import keras 
# %matplotlib inline

# %%
from keras.optimizers import Adam 
from keras import Sequential,Model

#A Sequential model is appropriate for a plain stack of layers where each layer has exactly one input tensor and one output tensor

#The core idea of Sequential API is simply arranging the Keras layers in a sequential order and so, it is called Sequential API.
from keras.layers import Dense,BatchNormalization,LeakyReLU,Input,Reshape,Dropout,Flatten,Activation

# Dense Layer is fully connected layer ,i.e hidden layer 
# BatchNormalization is a technique to normalize the output from previous layer 
# LeakyRel is a activation function 
# Reshape , it reshapes the image
# Dropout drop the nodes in the layer that are less useful 
from keras import datasets 
from keras.datasets import fashion_mnist

# Properties of the dataset 
# 70,000 images of clothes(grayscale),size (28,28,1)

# %% [markdown]
# Train Test Split

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

#storing the training data in a dataframe
train_df = pd.DataFrame(np.hstack([X_train.reshape(-1, 28*28),y_train.reshape(-1,1)]))

# %% [markdown]
# Discriminator Model

# %%
def build_discriminator(img_shape=(28,28,1),summary=True):
    model = Sequential()
    model.add(Input(shape=img_shape))
    model.add(Flatten()) #flatten() method is used for converting multi-dimensional array into one dimensional flatten array or say single dimensional array.
    model.add(Dense(512))  # 512 hidden units or nodes in a particular layer  # Hideen layer1
    model.add(LeakyReLU(0.3))  # LeakyReLU is a activation function  , 0.3 is the slope which is negative
    model.add(Dense(256))  # Hidden Layer 2
    model.add(LeakyReLU(0.3))
    model.add(Dense(1,activation='sigmoid'))  # Only 1 layer becoz it was for prediction of gans ,i.e true or false
    
    if summary:
        model.summary() 
    return model

# %%
discriminator = build_discriminator()
discriminator.compile(loss='binary_crossentropy',optimizer=Adam(0.0002, 0.5),metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 512)               401920
#
#  leaky_re_lu (LeakyReLU)     (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 256)               0
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 533,505
# Trainable params: 533,505
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Generator Model

# %%
def build_generator(z_dim=(100),output_shape=(28,28),summary=True): # z_dim gives the size of the noise vector
    model = Sequential()
    model.add(Input(shape=z_dim))
    model.add(Dense(256))
    model.add(LeakyReLU(0.3))
    model.add(BatchNormalization(momentum=0.8)) # batchnormalization takes the output from previous alyer and normalizes and sends to next input layer
    model.add(Dense(512))
    model.add(LeakyReLU(0.3))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(1024))
    model.add(LeakyReLU(0.3))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(np.prod(output_shape),activation='tanh'))
    model.add(Reshape(output_shape))
    
    if summary :
        model.summary()
    return model

# %%
generator = build_generator()
noise = tf.random.normal([1,100])
generated_image = generator(noise,training=False)
#plt.imshow(generated_image[0,:,:,0],cmap='gray') # this prints the noise image

# %% [markdown]
# GAN Model

# %%
def make_gan_model(generator, discriminator):
    model = tf.keras.Sequential()
    model.add(generator)
    model.add(discriminator)
    model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
discriminator = build_discriminator()
generator = build_generator()

Gan_Model = make_gan_model(generator, discriminator)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 784)               0
#
#  dense_10 (Dense)            (None, 512)               401920
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 512)               0
#
#  dense_11 (Dense)            (None, 256)               131328
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 256)               0
#
#  dense_12 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 533,505
# Trainable params: 533,505
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_13 (Dense)            (None, 256)               25856
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 256)               0
#
#  batch_normalization_3 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_14 (Dense)            (None, 512)               131584
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 512)               0
#
#  batch_normalization_4 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_15 (Dense)            (None, 1024)              525312
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 1024)              0
#
#  batch_normalization_5 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dense_16 (Dense)            (None, 784)               803600
#
#  reshape_1 (Reshape)         (None, 28, 28)            0
#
# =================================================================
# Total params: 1,493,520
# Trainable params: 1,489,936
# Non-trainable params: 3,584
# _________________________________________________________________

# %% [markdown]
# Training The GAN

# %%
def train(generator=None,discriminator=None,gan_model=None,epochs=50,batch_size=128,z_dim=100,sample_interval=200):
    (X_train, _), (_, _) = datasets.fashion_mnist.load_data()
    X_train = X_train /127.5  # Normalizing 
    
    
    
    
    for i in range(epochs):
        noise = np.random.normal(0,1,(batch_size,z_dim))
        
        discriminator.compile(loss='binary_crossentropy',optimizer=Adam(0.0002, 0.5),metrics=['accuracy'])

        
        real_imgs = X_train[np.random.randint(0,train_df.shape[0],batch_size)]
        print(real_imgs.shape)
        fake_imgs = generator.predict(noise)
        print(fake_imgs.shape)
        
        data = np.concatenate((fake_imgs,real_imgs),axis=0)
        labels = np.concatenate((np.zeros((batch_size,1)),np.ones((batch_size,1))),axis=0)
         
       
        
        disc_loss,disc_acc = discriminator.train_on_batch(data,labels)
        
        labels = np.ones((batch_size,1))   # Labels 
        #discriminator_loss = 0.5 *np.add(disc_loss_real,disc_loss_fake) 
        gen_loss = gan_model.train_on_batch(noise,labels)
        
        # training updates 
        print("%d [Discriminator Loss: %f,acc.: %.2f%%] [Generator Loss: %f]" % (epochs,disc_loss,100*disc_acc,gen_loss))
         
        # if epochs % sample_interval == 0:
        #     sample_images(epochs,generator)

# %%
# Noise for generator
z_dim = 100
z = Input(shape=(z_dim,))   # Input 
img = generator(z)

# Fix the discriminator
discriminator.trainable = False

# Get discriminator output
validity = discriminator(img)   # Output 

# Stack discriminator on top of generator
gan_model = Model(z, validity)
gan_model.compile(loss='binary_crossentropy', optimizer=Adam(0.0001, 0.5))
gan_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 100)]             0
#
#  sequential_4 (Sequential)   (None, 28, 28)            1493520
#
#  sequential_3 (Sequential)   (None, 1)                 533505
#
# =================================================================
# Total params: 2,027,025
# Trainable params: 1,489,936
# Non-trainable params: 537,089
# _________________________________________________________________

# %%
train(generator,discriminator,gan_model,epochs=100,batch_size=32 , sample_interval=200)
# Out:
# (32, 28, 28)
# 1/1 [==============================] - 0s 67ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.152339,acc.: 28.12%] [Generator Loss: 0.235557]
# (32, 28, 28)
# 1/1 [==============================] - 0s 38ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.208279,acc.: 32.81%] [Generator Loss: 0.210897]
# (32, 28, 28)
# 1/1 [==============================] - 0s 31ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.204584,acc.: 29.69%] [Generator Loss: 0.205780]
# (32, 28, 28)
# 1/1 [==============================] - 0s 32ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.248197,acc.: 29.69%] [Generator Loss: 0.190712]
# (32, 28, 28)
# 1/1 [==============================] - 0s 40ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.248611,acc.: 23.44%] [Generator Loss: 0.195674]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.271092,acc.: 25.00%] [Generator Loss: 0.198236]
# (32, 28, 28)
# 1/1 [==============================] - 0s 32ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.236009,acc.: 23.44%] [Generator Loss: 0.209635]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.321325,acc.: 26.56%] [Generator Loss: 0.198026]
# (32, 28, 28)
# 1/1 [==============================] - 0s 25ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.209038,acc.: 23.44%] [Generator Loss: 0.196987]
# (32, 28, 28)
# 1/1 [==============================] - 0s 32ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.264067,acc.: 17.19%] [Generator Loss: 0.185480]
# (32, 28, 28)
# 1/1 [==============================] - 0s 38ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.260478,acc.: 29.69%] [Generator Loss: 0.201576]
# (32, 28, 28)
# 1/1 [==============================] - 0s 33ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.313644,acc.: 26.56%] [Generator Loss: 0.175059]
# (32, 28, 28)
# 1/1 [==============================] - 0s 19ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.301075,acc.: 34.38%] [Generator Loss: 0.171937]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.384105,acc.: 26.56%] [Generator Loss: 0.142090]
# (32, 28, 28)
# 1/1 [==============================] - 0s 28ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.265345,acc.: 25.00%] [Generator Loss: 0.187915]
# (32, 28, 28)
# 1/1 [==============================] - 0s 32ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.309495,acc.: 21.88%] [Generator Loss: 0.166043]
# (32, 28, 28)
# 1/1 [==============================] - 0s 30ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.293357,acc.: 28.12%] [Generator Loss: 0.156360]
# (32, 28, 28)
# 1/1 [==============================] - 0s 16ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.359126,acc.: 34.38%] [Generator Loss: 0.146100]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.383773,acc.: 26.56%] [Generator Loss: 0.149648]
# (32, 28, 28)
# 1/1 [==============================] - 0s 26ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.373585,acc.: 35.94%] [Generator Loss: 0.146834]
# (32, 28, 28)
# 1/1 [==============================] - 0s 32ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.334784,acc.: 32.81%] [Generator Loss: 0.159795]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.372473,acc.: 32.81%] [Generator Loss: 0.151435]
# (32, 28, 28)
# 1/1 [==============================] - 0s 33ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.321099,acc.: 31.25%] [Generator Loss: 0.167627]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.304384,acc.: 25.00%] [Generator Loss: 0.162964]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.412237,acc.: 31.25%] [Generator Loss: 0.128458]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.345097,acc.: 26.56%] [Generator Loss: 0.154052]
# (32, 28, 28)
# 1/1 [==============================] - 0s 16ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.422707,acc.: 25.00%] [Generator Loss: 0.143409]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.346338,acc.: 17.19%] [Generator Loss: 0.152626]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.371662,acc.: 28.12%] [Generator Loss: 0.142408]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.387876,acc.: 31.25%] [Generator Loss: 0.140669]
# (32, 28, 28)
# 1/1 [==============================] - 0s 32ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.447772,acc.: 28.12%] [Generator Loss: 0.118684]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.457827,acc.: 34.38%] [Generator Loss: 0.127959]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.501939,acc.: 21.88%] [Generator Loss: 0.121772]
# (32, 28, 28)
# 1/1 [==============================] - 0s 16ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.478594,acc.: 18.75%] [Generator Loss: 0.132416]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.493121,acc.: 25.00%] [Generator Loss: 0.115778]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.456337,acc.: 26.56%] [Generator Loss: 0.128804]
# (32, 28, 28)
# 1/1 [==============================] - 0s 39ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.449024,acc.: 26.56%] [Generator Loss: 0.120584]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.563493,acc.: 23.44%] [Generator Loss: 0.106527]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.506526,acc.: 25.00%] [Generator Loss: 0.116275]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.506506,acc.: 29.69%] [Generator Loss: 0.109236]
# (32, 28, 28)
# 1/1 [==============================] - 0s 16ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.496577,acc.: 29.69%] [Generator Loss: 0.128567]
# (32, 28, 28)
# 1/1 [==============================] - 0s 25ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.603855,acc.: 21.88%] [Generator Loss: 0.099735]
# (32, 28, 28)
# 1/1 [==============================] - 0s 29ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.503818,acc.: 34.38%] [Generator Loss: 0.107115]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.585938,acc.: 29.69%] [Generator Loss: 0.097561]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.561914,acc.: 25.00%] [Generator Loss: 0.107176]
# (32, 28, 28)
# 1/1 [==============================] - 0s 23ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.619518,acc.: 21.88%] [Generator Loss: 0.106072]
# (32, 28, 28)
# 1/1 [==============================] - 0s 18ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.540958,acc.: 28.12%] [Generator Loss: 0.109762]
# (32, 28, 28)
# 1/1 [==============================] - 0s 28ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.572087,acc.: 29.69%] [Generator Loss: 0.101750]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.487632,acc.: 23.44%] [Generator Loss: 0.113293]
# (32, 28, 28)
# 1/1 [==============================] - 0s 30ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.713029,acc.: 23.44%] [Generator Loss: 0.077694]
# (32, 28, 28)
# 1/1 [==============================] - 0s 25ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.579602,acc.: 28.12%] [Generator Loss: 0.101559]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.536090,acc.: 17.19%] [Generator Loss: 0.106297]
# (32, 28, 28)
# 1/1 [==============================] - 0s 16ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.566121,acc.: 31.25%] [Generator Loss: 0.102921]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.620405,acc.: 31.25%] [Generator Loss: 0.095318]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.648192,acc.: 32.81%] [Generator Loss: 0.080692]
# (32, 28, 28)
# 1/1 [==============================] - 0s 32ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.632597,acc.: 23.44%] [Generator Loss: 0.094820]
# (32, 28, 28)
# 1/1 [==============================] - 0s 16ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.647092,acc.: 28.12%] [Generator Loss: 0.085286]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.629877,acc.: 28.12%] [Generator Loss: 0.083412]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.694117,acc.: 28.12%] [Generator Loss: 0.090698]
# (32, 28, 28)
# 1/1 [==============================] - 0s 16ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.668650,acc.: 21.88%] [Generator Loss: 0.087879]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.598057,acc.: 20.31%] [Generator Loss: 0.095354]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.688346,acc.: 23.44%] [Generator Loss: 0.089506]
# (32, 28, 28)
# 1/1 [==============================] - 0s 32ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.659347,acc.: 20.31%] [Generator Loss: 0.084827]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.638865,acc.: 28.12%] [Generator Loss: 0.088597]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.757822,acc.: 28.12%] [Generator Loss: 0.074337]
# (32, 28, 28)
# 1/1 [==============================] - 0s 16ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.646114,acc.: 32.81%] [Generator Loss: 0.083244]
# (32, 28, 28)
# 1/1 [==============================] - 0s 25ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.707285,acc.: 29.69%] [Generator Loss: 0.075720]
# (32, 28, 28)
# 1/1 [==============================] - 0s 27ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.685273,acc.: 26.56%] [Generator Loss: 0.079649]
# (32, 28, 28)
# 1/1 [==============================] - 0s 34ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.716138,acc.: 26.56%] [Generator Loss: 0.078957]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.781816,acc.: 29.69%] [Generator Loss: 0.067385]
# (32, 28, 28)
# 1/1 [==============================] - 0s 33ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.750439,acc.: 32.81%] [Generator Loss: 0.066633]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.607288,acc.: 25.00%] [Generator Loss: 0.089627]
# (32, 28, 28)
# 1/1 [==============================] - 0s 32ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.747898,acc.: 18.75%] [Generator Loss: 0.068329]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.744999,acc.: 29.69%] [Generator Loss: 0.072194]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.697323,acc.: 29.69%] [Generator Loss: 0.074515]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.806493,acc.: 25.00%] [Generator Loss: 0.076592]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.769143,acc.: 21.88%] [Generator Loss: 0.067807]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.764158,acc.: 28.12%] [Generator Loss: 0.069825]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.818392,acc.: 21.88%] [Generator Loss: 0.058417]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.808712,acc.: 29.69%] [Generator Loss: 0.069270]
# (32, 28, 28)
# 1/1 [==============================] - 0s 20ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.642104,acc.: 35.94%] [Generator Loss: 0.081387]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.717572,acc.: 34.38%] [Generator Loss: 0.076414]
# (32, 28, 28)
# 1/1 [==============================] - 0s 27ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.791001,acc.: 28.12%] [Generator Loss: 0.058488]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.853435,acc.: 31.25%] [Generator Loss: 0.057923]
# (32, 28, 28)
# 1/1 [==============================] - 0s 28ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.781549,acc.: 28.12%] [Generator Loss: 0.061829]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.769569,acc.: 34.38%] [Generator Loss: 0.058248]
# (32, 28, 28)
# 1/1 [==============================] - 0s 25ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.764258,acc.: 18.75%] [Generator Loss: 0.068013]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.846832,acc.: 20.31%] [Generator Loss: 0.064676]
# (32, 28, 28)
# 1/1 [==============================] - 0s 31ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.859996,acc.: 23.44%] [Generator Loss: 0.060709]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.884476,acc.: 29.69%] [Generator Loss: 0.052790]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.789977,acc.: 28.12%] [Generator Loss: 0.067923]
# (32, 28, 28)
# 1/1 [==============================] - 0s 25ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.834638,acc.: 23.44%] [Generator Loss: 0.060872]
# (32, 28, 28)
# 1/1 [==============================] - 0s 25ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.817342,acc.: 23.44%] [Generator Loss: 0.062097]
# (32, 28, 28)
# 1/1 [==============================] - 0s 25ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.845886,acc.: 31.25%] [Generator Loss: 0.066681]
# (32, 28, 28)
# 1/1 [==============================] - 0s 32ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.795990,acc.: 31.25%] [Generator Loss: 0.063789]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.944724,acc.: 29.69%] [Generator Loss: 0.048677]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.808301,acc.: 21.88%] [Generator Loss: 0.061243]
# (32, 28, 28)
# 1/1 [==============================] - 0s 24ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.955271,acc.: 26.56%] [Generator Loss: 0.055743]
# (32, 28, 28)
# 1/1 [==============================] - 0s 25ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.977960,acc.: 18.75%] [Generator Loss: 0.056313]
# (32, 28, 28)
# 1/1 [==============================] - 0s 20ms/step
# (32, 28, 28)
# 100 [Discriminator Loss: 1.948975,acc.: 31.25%] [Generator Loss: 0.049761]

# %%
batch_size=32
noise = np.random.normal(0,1,(batch_size,z_dim))
gen_imgs = generator.predict(noise)
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %% [markdown]
# Saving The data

# %%
test_df = pd.DataFrame(gen_imgs.reshape(32,28*28))
test_df.to_csv('test.csv', index=False, header=False)
